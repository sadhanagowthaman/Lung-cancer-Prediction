# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Present.csv')

# %%
data.head()
# Out:
#                   ALGORITHM   ACCURACY
# 0      LOGISITIC REGRESSION  85.185185
# 1  DECISION TREE CLASSIFIER  98.148148
# 2  RANDOM FOREST CLASSIFIER  97.222222
# 3   SUPPORT VECTOR  MACHINE  60.185185

# %%
import matplotlib.pyplot as plt
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i],)
x=["Logistic Regression","Decision tree","Random Forest","Support vector"]
y=[85.185185,98.148148,97.222222,60.185185]
plt.bar(x,y,color="purple",width=0.6)
addlabels(x,y)
plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.title("Alogirthms accuracy value")
plt.show()
